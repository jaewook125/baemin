# %%
import os
import json
import requests
import random
import time
from django.core.files.base import ContentFile
from shop.models import Category, Shop, Item
from urllib.parse import urljoin
from fake_useragent import UserAgent

# %%
class Yogiyo:
    HOST = 'https://www.yogiyo.co.kr'
    
    def __init__(self, headers):
        self.headers = headers
    
    def get_restaurant_list_by_geo(self, zip_code):
        url = self.HOST + '/api/v1/restaurants-geo/'
        params = dict(
            items=20,
            order='rank',
            page=0,
            search='',
            zip_code=zip_code,
        )
        res = requests.get(url, params=params, headers=self.headers)
        return res.json()
    
    def get_menu_list(self, restaurant_id): #레스토랑 아이디를 지정해주면 해당 레스토랑의 메뉴정보를 읽어옴
        base_url = self.HOST + '/api/v1/restaurants/{restaurant_id}/menu/?add_photo_menu=original'
        url = base_url.format(restaurant_id=restaurant_id)
        res = requests.get(url, headers=self.headers)
        return res.json()

# %% [markdown]
# ## 활용 : 식당등록

# %%
user_agent = UserAgent() #유저 에이전트를 하나 만들어준다
#fake_useragent 에서 가지고온것

# %%
headers = {
    'X-ApiKey' : 'iphoneap',
    'X-ApiSecret' : 'fe5183cc3dea12bd0ce299cf110a75a2',
    'X-MOD-SBB-CTYPE' : 'xhr',
    'User-Agent' : user_agent.Chrome,
}

yogiyo = Yogiyo(headers)

# %%
headers
# Out:
# {'X-ApiKey': 'iphoneap',
#  'X-ApiSecret': 'fe5183cc3dea12bd0ce299cf110a75a2',
#  'X-MOD-SBB-CTYPE': 'xhr',
#  'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.124 Safari/537.36'}

# %%
yogiyo = Yogiyo(headers)

# %%
zip_code = '143201' #필요한 zip코드를 찾아서 넣으면됌
restaurants = yogiyo.get_restaurant_list_by_geo('143201')['restaurants']
restaurants
# Out:
# [{'rating': 200033.079338906,
#   'subtitle': '',
#   'additional_discount_currently_active': True,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': True,
#   'franchise_id': 4,
#   'phone_downlisted': False,
#   'franchise_name': '(주)7번가사람들 / 7번가피자',
#   'review_image_count': 129,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352589652',
#   'additional_discount_only_for_user': True,
#   'has_terminal': True,
#   'categories': ['프랜차이즈', '피자양식'],
#   'min_order_amount': 15000,
#   'distance': 0.75166836208885,
#   'logo_url': '/media/restaurant_logos/7번가피자_20160205_Franchise이미지약정서_crop_200x200_yBpjJO6.jpg',
#   'except_cash': False,
#   'name': '7번가피자-구의점',
#   'section_pos': 1,
#   'owner_reply_count': 0,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 22:30',
#   'keywords': '7번가피자-구의점 패밀리박스메뉴 패밀리박스（R） 음료메뉴 콜라1.25L 패밀리박스메뉴 패밀리박스（L） 사이드메뉴 디핑소스（30g） 오리지날피자R 슈퍼콤비네이션피자R 사이드메뉴 핫윙（4pcs） 프리미엄스페셜피자R 7번가스페셜피자R 프리미엄박스메뉴 프리미엄박스（R） 사이드메뉴 오븐스파게티 사이드메뉴 수제피클',
#   'new_rating': 0.9939954393766581,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0878279,
#   'list_pos': 1,
#   'id': 230761,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 411,
#   'relay_methods': ['email', 'sms_relay'],
#   'section': 'hotdeal',
#   'loyal_score': 13.6082277948607,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 5000,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '',
#   'tags': ['CESCO', 'excellent'],
#   'address': '서울 광진구 구의동 80-8 1층',
#   'lat': 37.5476028,
#   'end': '22:30:00',
#   'slug': '7번가피자-구의점',
#   'review_avg': 4.62773722627737,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200062.525986224,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 12000원 이상',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': 86,
#   'phone_downlisted': False,
#   'franchise_name': '주식회사케이에프씨 / KFC',
#   'review_image_count': 28,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050712921999',
#   'additional_discount_only_for_user': False,
#   'has_terminal': False,
#   'categories': ['피자양식', '프랜차이즈', '치킨'],
#   'min_order_amount': 12000,
#   'distance': 1.3531179165485947,
#   'logo_url': '/media/restaurant_logos/KFC__20171106_Franchise이미지약정서_crop_200x200.jpg',
#   'except_cash': False,
#   'name': 'KFC-세종대점',
#   'section_pos': 1,
#   'relay_methods': ['email', 'relayo_relay'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 00:00',
#   'keywords': 'KFC-세종대점 버거세트 타워버거세트¸ 스낵&사이드 에그타르트¸ 치킨메뉴 핫크리스피치킨1조각¸ 버거세트 징거버거세트¸ 스낵&사이드 비스켓¸ 치킨메뉴 오리지널치킨1조각¸ 치킨세트 치킨도버거도세트 스낵&사이드 코울슬로 스낵&사이드 후렌치후라이¸ 스낵&사이드 콘샐러드',
#   'new_rating': 2.2578743809302573,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.073569298591,
#   'list_pos': 2,
#   'id': 261386,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 230,
#   'owner_reply_count': 0,
#   'section': 'contract',
#   'loyal_score': 48.2124491059994,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '',
#   'tags': ['relayo'],
#   'address': '서울 광진구 화양동 225',
#   'lat': 37.5472166426971,
#   'end': '00:00:00',
#   'slug': 'kfc-세종대점',
#   'review_avg': 3.90869565217391,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200063.32888544,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 6000원 이상',
#   'is_available_delivery': True,
#   'threshold': 8000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 273,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050712915885',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['1인분주문', '한식'],
#   'min_order_amount': 6000,
#   'distance': 1.2575092427563939,
#   'logo_url': '/media/restaurant_logos/미스몽도시락-건대점_20170406_가맹로고이미지약정서_crop_200x200.jpg',
#   'except_cash': False,
#   'name': '미스몽도시락-건대점',
#   'section_pos': 2,
#   'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#   'one_dish': 1,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '10:00 - 20:30',
#   'keywords': '미스몽도시락-건대점 한식메뉴 제육비빔밥 오므라이스세트메뉴 오므라이스세트（수제돈까스＋오므라이스） 한식메뉴 제육볶음 한식메뉴 돼지불백 별미메뉴 라볶이 볶음밥메뉴 김치볶음밥＋계란후라이 한식메뉴 옛날도시락＋계란후라이 양식메뉴 수제돈까스 추가메뉴 계란추가 김밥메뉴 참치김밥',
#   'new_rating': 2.1290980134843815,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.077122034375,
#   'list_pos': 3,
#   'id': 255368,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 1228,
#   'owner_reply_count': 0,
#   'section': 'contract',
#   'loyal_score': 44.5149965508915,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '10:00:00',
#   'description': '',
#   'tags': ['excellent'],
#   'address': '서울 광진구 자양동 607-18 1층',
#   'lat': 37.5325168923834,
#   'end': '20:30:00',
#   'slug': '미스몽도시락-건대점TFW9UP',
#   'review_avg': 4.47231270358306,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200042.092599351,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 12900원 이상',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': 3,
#   'phone_downlisted': False,
#   'franchise_name': '(주)반올림피자샵 / 피자샵',
#   'review_image_count': 213,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352595317',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['피자양식', '프랜차이즈'],
#   'min_order_amount': 12900,
#   'distance': 0.729215271912644,
#   'logo_url': '/media/restaurant_logos/피자샵_20160325_Franchise이미지약정서_crop_200x200_HGiPw9r.jpg',
#   'except_cash': False,
#   'name': '피자샵-자양성수점',
#   'section_pos': 3,
#   'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '12:00 - 23:30',
#   'keywords': '피자샵-자양성수점 추가메뉴 수제갈릭소스 추가메뉴 코카콜라1.25L 세트메뉴 세트1（오리지널피자L＋사이드＋콜라500mL） 하프앤하프피자메뉴 하프앤하프피자L 세트메뉴 세트5（오리지널피자R＋사이드＋콜라500mL） 추가메뉴 수제피클 하프앤하프피자메뉴 하프앤하프피자R 추가메뉴 스프라이트1.5L 추가메뉴 코카콜라500mL 사이드메뉴 치즈오븐스파게티',
#   'new_rating': 1.3637070734895074,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0798521,
#   'list_pos': 4,
#   'id': 235854,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 732,
#   'owner_reply_count': 0,
#   'section': 'contract',
#   'loyal_score': 22.7387531968009,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '12:00:00',
#   'description': '',
#   'tags': ['excellent', 'CESCO'],
#   'address': '서울 광진구 자양동 222-8 1층',
#   'lat': 37.5372142,
#   'end': '23:30:00',
#   'slug': '피자샵-자양성수점',
#   'review_avg': 4.53551912568306,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200019.308660912,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 20000원 이상',
#   'is_available_delivery': True,
#   'threshold': 8000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 6,
#   'sms_bonus': True,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 8,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050712932839',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['야식', '일식돈까스'],
#   'min_order_amount': 20000,
#   'distance': 2.3244940695865797,
#   'logo_url': '/media/restaurant_logos/회07_20131205_foodon_crop_200x200_OTy3Hv7.jpg',
#   'except_cash': False,
#   'name': '바다여행',
#   'section_pos': 4,
#   'owner_reply_count': 6,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '15:40 - 03:00',
#   'keywords': '바다여행 파티특선세트메뉴 파티특선세트（모둠회특大＋랍스터찜1kg＋해산물모둠＋산낙지or낙지호롱＋새우튀김＋초밥＋매운탕） 무침특선메뉴 낙지초무침 탕특선메뉴 서더리지리맑은탕 물회메뉴 특선모둠물회 활어단품특선메뉴 도다리세꼬시 식사메뉴 활어초밥10pcs 구이특선메뉴 가리비버터구이 세트특선메뉴 세트특선（광어＋우럭＋활랍스터찜500g） 세트특선메뉴 세트특선（광어＋우럭＋새우튀김） 식사메뉴 공기밥',
#   'new_rating': 0.11678095590129675,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.08213964492,
#   'list_pos': 5,
#   'id': 271864,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 6,
#   'relay_methods': ['email', 'sms_relay'],
#   'section': 'contract',
#   'loyal_score': -0.458005754534682,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': True,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '15:40:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 중곡동 41-17 양명빌딩 1층',
#   'lat': 37.5614944400072,
#   'end': '03:00:00',
#   'slug': '바다여행1VA2QJ',
#   'review_avg': 4.83333333333333,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200035.875812644,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 21000원 이상',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': '2018-04-13T00:59:59.999999',
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 171,
#   'sms_bonus': True,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 81,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050712912415',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['야식', '족발보쌈'],
#   'min_order_amount': 21000,
#   'distance': 1.668068918331462,
#   'logo_url': '/media/restaurant_logos/족발04_20131128_FoodAD_crop_200x200_3CRMM2d.jpg',
#   'except_cash': False,
#   'name': '천하대만족-중곡점',
#   'section_pos': 5,
#   'relay_methods': ['email', 'sms_relay'],
#   'one_dish': 0,
#   'discount_percent': 10,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:30 - 01:00',
#   'keywords': '천하대만족-중곡점 세트메뉴 족보세트2~3人（족발＋보쌈＋쟁반국수） 로스팅훈제족발메뉴 혼족（1인용） 로스팅훈제족발메뉴 훈제족발 로스팅훈제족발메뉴 반반족발（족발＋매운족발） 보쌈메뉴 보쌈 세트메뉴 족보세트1~2人（족발＋보쌈＋쟁반국수） 로스팅훈제족발메뉴 불족발 사이드메뉴 쟁반막국수中 세트메뉴 족보세트4~5人（족발＋보쌈＋쟁반국수） 세트메뉴 가족세트（매운족발＋족발＋보쌈＋쟁반국수）',
#   'new_rating': 0.9191821629397117,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0889371,
#   'list_pos': 6,
#   'id': 252014,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 189,
#   'owner_reply_count': 171,
#   'section': 'contract',
#   'loyal_score': 16.3198986651501,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:30:00',
#   'description': '',
#   'tags': ['excellent'],
#   'address': '서울 광진구 중곡동 92-23 1층',
#   'lat': 37.5557985,
#   'end': '01:00:00',
#   'slug': '천하대만족-중곡점0BYHWE',
#   'review_avg': 4.68783068783069,
#   'discount_from': '2018-04-12T12:00:00',
#   'top28': False,
#   'url': '',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200034.32632341,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 37,
#   'sms_bonus': False,
#   'franchise_id': 37,
#   'phone_downlisted': False,
#   'franchise_name': '(유)비에이치씨 / BHC치킨',
#   'review_image_count': 38,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352589075',
#   'additional_discount_only_for_user': False,
#   'has_terminal': False,
#   'categories': ['야식', '치킨', '프랜차이즈'],
#   'min_order_amount': 15000,
#   'distance': 0.43539962827444373,
#   'logo_url': '/media/restaurant_logos/BHC치킨_20150903_Franchise이미지약정서_crop_200x200_oJ00D1r.JPG',
#   'except_cash': False,
#   'name': 'BHC-구의역점',
#   'section_pos': 6,
#   'relay_methods': ['email', 'sms_relay', 'relayo_relay'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '15:00 - 02:00',
#   'keywords': 'BHC-구의역점 맛초킹 맛초킹（한마리） 뿌링클 뿌링클 후라이드 해바라기후라이드치킨 후라이드 후라이드반／양념반 콜라／무／소스 콜라1.25L¸ 맵스터 맵스터 뿌링클 순살뿌링클 후라이드 해바라기핫후라이드치킨 양념 양념치킨 커리퀸 커리퀸',
#   'new_rating': 1.3371215255973392,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0843067,
#   'list_pos': 7,
#   'id': 230295,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 204,
#   'owner_reply_count': 37,
#   'section': 'contract',
#   'loyal_score': 20.6050362813057,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '15:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 구의동 246-31',
#   'lat': 37.5374739,
#   'end': '02:00:00',
#   'slug': 'bhc-구의역점',
#   'review_avg': 4.40196078431373,
#   'discount_from': None,
#   'top28': True,
#   'url': '',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200042.668757932,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 17900원 이상',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': 26,
#   'phone_downlisted': False,
#   'franchise_name': '(주)리치빔 / 피자나라치킨공주',
#   'review_image_count': 144,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352561381',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['프랜차이즈', '피자양식'],
#   'min_order_amount': 17900,
#   'distance': 1.3084447640997263,
#   'logo_url': '/media/restaurant_logos/피자나라치킨공주_20140313_Franchise_crop_200x200_12.jpg',
#   'except_cash': False,
#   'name': '피자나라치킨공주(자양점)',
#   'section_pos': 7,
#   'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '12:00 - 23:45',
#   'keywords': '피자나라치킨공주(자양점) 세트L메뉴 피치세트L 사이드메뉴 리얼갈릭소스 세트M메뉴 더블포테이토피치세트M 세트M메뉴 스위트불고기피치세트M 세트M메뉴 순살피치세트M 세트L메뉴 더블포테이토피치세트L 사이드메뉴 양념소스 사이드메뉴 콜라1.25L 사이드메뉴 푸실리스파게티 세트M메뉴 고구마피치세트M',
#   'new_rating': 1.302234625017467,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.076372946302,
#   'list_pos': 8,
#   'id': 2063,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 740,
#   'owner_reply_count': 0,
#   'section': 'contract',
#   'loyal_score': 24.0980894459353,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '12:00:00',
#   'description': '',
#   'tags': ['excellent'],
#   'address': '서울 광진구 자양동 608-31',
#   'lat': 37.5324453888417,
#   'end': '23:45:00',
#   'slug': '피자나라치킨공주(자양점)',
#   'review_avg': 4.28108108108108,
#   'discount_from': None,
#   'top28': False,
#   'url': 'http://www.pncg.co.kr',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200038.680049299,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 11000원 이상',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 96,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352576836',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['피자양식'],
#   'min_order_amount': 11000,
#   'distance': 0.7559927337089034,
#   'logo_url': '/media/restaurant_logos/참살이임실치즈피자_20131201_가맹로고_crop_200x200_cz9pwdk.jpg',
#   'except_cash': False,
#   'name': '참살이임실치즈피자',
#   'section_pos': 8,
#   'relay_methods': ['email', 'box_helicom'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:30 - 00:30',
#   'keywords': '참살이임실치즈피자 음료／소스 콜라1.25L 음료／소스 갈릭디핑 참세트메뉴 세트1（피자＋치즈오븐＋요거트샐러드＋콜라500mL） 참살이특별행사 피자M＋피자M 음료／소스 콜라500mL 음료／소스 사이다1.25L 오리지널피자M 콤비네이션피자M 오리지널피자L 슈퍼슈프림피자L 오리지널피자L 콤비네이션피자L 음료／소스 수제피클',
#   'new_rating': 1.2428385429778634,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0790215,
#   'list_pos': 9,
#   'id': 218618,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 474,
#   'owner_reply_count': 0,
#   'section': 'contract',
#   'loyal_score': 19.8509272429911,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:30:00',
#   'description': '',
#   'tags': ['CESCO'],
#   'address': '서울 광진구 자양1동 773-9',
#   'lat': 37.5378618,
#   'end': '00:30:00',
#   'slug': '참살이임실치즈피자IURH2N',
#   'review_avg': 4.47679324894515,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200019.0,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 2000원, 최소 주문 금액 13000원',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 4,
#   'sms_bonus': True,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 3,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 2000,
#   'additional_discount_pickup': 0,
#   'phone': '050712932412',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['치킨'],
#   'min_order_amount': 13000,
#   'distance': 0.5244010086830713,
#   'logo_url': '/media/restaurant_logos/닭강정01_20131128_FoodAD_crop_200x200_m74IoAe.jpg',
#   'except_cash': False,
#   'name': '착한삼촌닭강정',
#   'section_pos': 9,
#   'owner_reply_count': 4,
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '14:00 - 22:50',
#   'keywords': '착한삼촌닭강정 주류 바이드만슈바르츠캔（500mL） 주류 카스캔（500mL） 음료메뉴 콜라1.25L 음료메뉴 스프라이트355mL 음료메뉴 스프라이트1.25L 메인메뉴 갈릭허니（달콤） 메인메뉴 오리지날（매콤） 소스메뉴 갈릭허니소스추가 주류 쉐퍼호퍼바이젠캔（500mL） 주류 칭따오캔（500mL）',
#   'new_rating': 0.4951197982633857,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0831925,
#   'list_pos': 10,
#   'id': 271278,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 4,
#   'relay_methods': ['email', 'sms_relay'],
#   'section': 'contract',
#   'loyal_score': 0.0,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': True,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '14:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 구의동 253-19 센트럴빌 1층 104-c호',
#   'lat': 37.5447179999388,
#   'end': '22:50:00',
#   'slug': '착한삼촌닭강정',
#   'review_avg': 5.0,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200019.766583474,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': '2018-04-12T19:59:59.999999',
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 19,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352559979',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['치킨', '야식'],
#   'min_order_amount': 15000,
#   'distance': 3.0466929597465344,
#   'logo_url': '/media/restaurant_logos/후라이드03_20120524_FoodAD_crop_200x200_236.jpg',
#   'except_cash': False,
#   'name': '위대한치킨(24시)',
#   'section_pos': 10,
#   'relay_methods': ['email', 'box_helicom'],
#   'one_dish': 0,
#   'discount_percent': 10,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '10:00 - 09:59',
#   'keywords': '위대한치킨(24시) 치킨메뉴 순살치킨 치킨메뉴 후라이드치킨 치킨메뉴 양념치킨 음료 콜라1.25L 치킨메뉴 핫후라이드 음료 콜라500ml 음료 사이다1.25L 음료 사이다500ml 치킨메뉴 치킨뱅이 치킨메뉴 골뱅이무침',
#   'new_rating': 0.507166071187504,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0858896,
#   'list_pos': 11,
#   'id': 20524,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 188,
#   'owner_reply_count': 0,
#   'section': 'contract',
#   'loyal_score': 12.6791517796876,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '10:00:00',
#   'description': '',
#   'tags': ['CESCO'],
#   'address': '서울 광진구 중곡동 16',
#   'lat': 37.5682956,
#   'end': '09:59:00',
#   'slug': '위대한치킨(24시)',
#   'review_avg': 3.6968085106383,
#   'discount_from': '2018-04-12T14:00:00',
#   'top28': False,
#   'url': '',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200040.963371051,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 1000원, 최소 주문 금액 13000원',
#   'is_available_delivery': True,
#   'threshold': 8000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': True,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 64,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 1000,
#   'additional_discount_pickup': 0,
#   'phone': '050712902866',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['일식돈까스', '한식', '피자양식'],
#   'min_order_amount': 13000,
#   'distance': 1.3860462853859725,
#   'logo_url': '/media/restaurant_logos/돈까스04_20131128_FoodAD_crop_200x200_KeABtBq.jpg',
#   'except_cash': False,
#   'name': '후레쉬팩토리-광진점',
#   'section_pos': 11,
#   'relay_methods': ['email', 'sms_relay'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 22:00',
#   'keywords': '후레쉬팩토리-광진점 PORKCUTLET 수제등심돈가스 SIDEMENU 새우튀김（개당） PORKCUTLET 치즈돈가스 STEAK 스테이크&볶음밥 NOODLE 양지쌀국수 BOWLofRICE 치킨마요덮밥 STEAK 스테이크（200g） SIDEMENU 등심돈가스（추가） PORKCUTLET 모듬가스 FRIEDRICE 참치김치볶음밥',
#   'new_rating': 1.2134710395136334,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.073088,
#   'list_pos': 12,
#   'id': 242768,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 275,
#   'owner_reply_count': 0,
#   'section': 'contract',
#   'loyal_score': 22.2670074147707,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '',
#   'tags': ['excellent'],
#   'address': '서울 광진구 화양동 213 지하',
#   'lat': 37.5471537,
#   'end': '22:00:00',
#   'slug': '후레쉬팩토리-광진점',
#   'review_avg': 4.38181818181818,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200032.52273841,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': 37,
#   'phone_downlisted': False,
#   'franchise_name': '(유)비에이치씨 / BHC치킨',
#   'review_image_count': 58,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352582126',
#   'additional_discount_only_for_user': False,
#   'has_terminal': False,
#   'categories': ['프랜차이즈', '치킨'],
#   'min_order_amount': 15000,
#   'distance': 0.8668002181269462,
#   'logo_url': '/media/restaurant_logos/BHC치킨_20150903_Franchise이미지약정서_crop_200x200_yoAzedk.JPG',
#   'except_cash': False,
#   'name': 'BHC-광나루점',
#   'section_pos': 12,
#   'relay_methods': ['email', 'sms_relay', 'relayo_relay'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '12:00 - 00:30',
#   'keywords': 'BHC-광나루점 맛초킹 맛초킹（한마리） 후라이드 해바라기후라이드치킨 후라이드 후라이드반／양념반 뿌링클 뿌링클 커리퀸 커리퀸 콜라／무／소스 콜라1.25L¸ 뿌링클 순살뿌링클 양념 양념치킨 맵스터 맵스터 후라이드 해바라기핫후라이드치킨',
#   'new_rating': 1.1742230679226986,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0962915,
#   'list_pos': 13,
#   'id': 224001,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 391,
#   'owner_reply_count': 0,
#   'section': 'contract',
#   'loyal_score': 18.6895777887022,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '12:00:00',
#   'description': '',
#   'tags': ['relayo'],
#   'address': '서울 광진구 광장동 566 103호 (청구상가)',
#   'lat': 37.5425784,
#   'end': '00:30:00',
#   'slug': 'bhc치킨-광나루점',
#   'review_avg': 4.48593350383632,
#   'discount_from': None,
#   'top28': True,
#   'url': '',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200036.757831869,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 13500원 이상',
#   'is_available_delivery': True,
#   'threshold': 8000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 222,
#   'sms_bonus': True,
#   'franchise_id': 405,
#   'phone_downlisted': False,
#   'franchise_name': '주식회사정담F&B / 배달삼겹돼지되지',
#   'review_image_count': 120,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050712910607',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['한식'],
#   'min_order_amount': 13500,
#   'distance': 0.5781940935604856,
#   'logo_url': '/media/restaurant_logos/배달삼겹돼지되지_20171122_Franchise이미지약정서_crop_200x200_qq5bajw.jpg',
#   'except_cash': False,
#   'name': '배달삼겹돼지되지-구의점',
#   'section_pos': 13,
#   'relay_methods': ['email', 'sms_relay'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 23:00',
#   'keywords': '배달삼겹돼지되지-구의점 도시락메뉴 오리지날솔로도시락（200g） 고기메뉴 오리지날 고기메뉴 반반양념 도시락메뉴 양념솔로도시락（200g） 고기메뉴 양념 주류 카스 도시락메뉴 에네르기파삼겹솔로도시락（200g） 주류 참이슬후레쉬 주류 처음처럼 고기메뉴 에네르기파삼겹',
#   'new_rating': 1.173845627215939,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.092347494384,
#   'list_pos': 14,
#   'id': 250260,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 223,
#   'owner_reply_count': 222,
#   'section': 'contract',
#   'loyal_score': 17.2371111482009,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 구의동 203-13 1층',
#   'lat': 37.5435328805089,
#   'end': '23:00:00',
#   'slug': '배달삼겹돼지되지-구의점',
#   'review_avg': 4.65919282511211,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200019.966278834,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': '2018-04-12T23:59:59.999999',
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 87,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352569080',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['치킨', '프랜차이즈'],
#   'min_order_amount': 15000,
#   'distance': 1.9856931845058068,
#   'logo_url': '/media/restaurant_logos/네네치킨_20131201_Franchise_crop_200x200_pHdX8dm.jpg',
#   'except_cash': False,
#   'name': '네네치킨-군자송정점',
#   'section_pos': 14,
#   'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#   'one_dish': 0,
#   'discount_percent': 10,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:00 - 00:40',
#   'keywords': '네네치킨-군자송정점 치킨메뉴 양념반＋후라이드반 스노윙메뉴 스노윙치즈＋양념 치킨메뉴 후라이드 스노윙메뉴 스노윙치즈＋쇼킹핫 스노윙메뉴 스노윙치킨 치킨메뉴 양념치킨 치킨메뉴 오리엔탈파닭 치킨메뉴 순살후라이드 신메뉴 순살반반（소이갈릭반＋스노윙치즈반） 스노윙메뉴 스노윙치즈＋스노윙야채',
#   'new_rating': 0.3344361663519503,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0722369,
#   'list_pos': 15,
#   'id': 69744,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 542,
#   'owner_reply_count': 0,
#   'section': 'contract',
#   'loyal_score': 3.28937008132779,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:00:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 군자동 117-23번지 1층 네네치킨',
#   'lat': 37.5545998,
#   'end': '00:40:00',
#   'slug': '네네치킨-군자송정점',
#   'review_avg': 4.36531365313653,
#   'discount_from': '2018-04-12T16:00:00',
#   'top28': False,
#   'url': '',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200034.812775672,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 8000원 이상',
#   'is_available_delivery': True,
#   'threshold': 5000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 1,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 15,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050712916360',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['중식'],
#   'min_order_amount': 8000,
#   'distance': 0.504892397005831,
#   'logo_url': '/media/restaurant_logos/볶음밥01_20131128_FoodAD_crop_200x200_EF4kv1h.jpg',
#   'except_cash': False,
#   'name': '신중국관',
#   'section_pos': 15,
#   'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '10:30 - 20:40',
#   'keywords': '신중국관 면메뉴 짜장면 반반메뉴 탕짜면 세트메뉴 세트1.（탕수육＋짜장1） 반반메뉴 탕볶밥 면메뉴 간짜장 면메뉴 짬뽕 반반메뉴 탕짬면 세트메뉴 세트2.（탕수육＋짜장2） 밥메뉴 볶음밥 면메뉴 불쟁반짜장',
#   'new_rating': 1.1546436586079099,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.085885591623,
#   'list_pos': 16,
#   'id': 255819,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 117,
#   'owner_reply_count': 1,
#   'section': 'contract',
#   'loyal_score': 16.3905534502269,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '10:30:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 구의동 68-34 1층',
#   'lat': 37.5453989810203,
#   'end': '20:40:00',
#   'slug': '신중국관9T9P1L',
#   'review_avg': 4.17094017094017,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200034.270764684,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 10000원 이상',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': 69,
#   'phone_downlisted': False,
#   'franchise_name': '(주)롯데지알에스 / 롯데리아',
#   'review_image_count': 32,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050712900938',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['1인분주문', '프랜차이즈', '피자양식'],
#   'min_order_amount': 10000,
#   'distance': 0.5513033104039091,
#   'logo_url': '/media/restaurant_logos/롯데리아_20160408_Franchise이미지약정서_crop_200x200_s63Nq1g.jpg',
#   'except_cash': True,
#   'name': '롯데리아-구의역점',
#   'section_pos': 16,
#   'relay_methods': ['email', 'box_helicom'],
#   'one_dish': 1,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '10:00 - 02:00',
#   'keywords': '롯데리아-구의역점 세트 핫크리스피버거세트 디저트 치즈스틱 세트 불고기버거세트 디저트 포테이토 디저트 양념감자 버거 불고기버거 디저트 롱치즈스틱 디저트 콘샐러드 버거 새우버거 드링크 콜라1.25L（PET）',
#   'new_rating': 1.1155483425554822,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0841259,
#   'list_pos': 17,
#   'id': 240891,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 280,
#   'owner_reply_count': 0,
#   'section': 'contract',
#   'loyal_score': 15.6452251159066,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '10:00:00',
#   'description': '',
#   'tags': ['CESCO'],
#   'address': '서울 광진구 자양동 216-21 1층 2호',
#   'lat': 37.5363814,
#   'end': '02:00:00',
#   'slug': '롯데리아-구의역점',
#   'review_avg': 4.31785714285714,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'payment_methods': ['online'],
#   'takeout': False},
#  {'rating': 200037.483781133,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 10000원 이상',
#   'is_available_delivery': True,
#   'threshold': 5000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 143,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050352561639',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['야식', '중식'],
#   'min_order_amount': 10000,
#   'distance': 1.546156379988131,
#   'logo_url': '/media/restaurant_logos/탕수육01_20120524_FoodAD_crop_200x200_11.jpg',
#   'except_cash': False,
#   'name': '요리왕',
#   'section_pos': 17,
#   'relay_methods': ['email', 'box_helicom'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '10:00 - 03:00',
#   'keywords': '요리왕 면류 짜장 요리왕세트메뉴 B세트.탕수육＋짜장＋짬뽕 면류 짬뽕 면류 간짜장 요리부 탕수육 돈까스&만두 군만두 요리왕세트메뉴 A세트.탕수육＋짜장2 반반메뉴 탕볶밥 면류 삼선쟁반짜장 반반메뉴 탕짜면',
#   'new_rating': 1.1071151960550258,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0695051,
#   'list_pos': 18,
#   'id': 7132,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 1704,
#   'owner_reply_count': 0,
#   'section': 'contract',
#   'loyal_score': 20.4086618013163,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '10:00:00',
#   'description': '',
#   'tags': ['CESCO', 'excellent'],
#   'address': '서울 광진구 자양4동 2-53',
#   'lat': 37.5381341,
#   'end': '03:00:00',
#   'slug': '요리왕2',
#   'review_avg': 3.7118544600939,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200008.165866938,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '최소 주문 금액 12000원 이상',
#   'is_available_delivery': True,
#   'threshold': 10000,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': '2018-04-12T21:59:59.999999',
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': True,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 9,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 0,
#   'additional_discount_pickup': 0,
#   'phone': '050712914670',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['피자양식'],
#   'min_order_amount': 12000,
#   'distance': 1.0328757250770402,
#   'logo_url': '/media/restaurant_logos/쉬림프골드피자01_20131128_FoodAD_crop_200x200_ZHjh1SV.jpg',
#   'except_cash': False,
#   'name': '파파라파피자',
#   'section_pos': 18,
#   'relay_methods': ['email', 'sms_relay'],
#   'one_dish': 0,
#   'discount_percent': 10,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '11:30 - 23:00',
#   'keywords': '파파라파피자 음료 콜라1.25L L피자메뉴 슈퍼슈프림L 추가메뉴 갈릭소스 L피자메뉴 콤비네이션L L피자메뉴 포테이토L L피자메뉴 페퍼로니L 음료 콜라500mL 추가메뉴 핫소스 사이드메뉴 치즈오븐스파게티 사이드메뉴 치킨봉（7조각）',
#   'new_rating': 0.2995078083667667,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.09745446427,
#   'list_pos': 19,
#   'id': 254198,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 29,
#   'owner_reply_count': 0,
#   'section': 'contract',
#   'loyal_score': -2.34792616544563,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '11:30:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 구의동 631-1 현대프라임아파트 프라임프라자상가 104호',
#   'lat': 37.5372392816313,
#   'end': '23:00:00',
#   'slug': '피자파파라파',
#   'review_avg': 4.24137931034483,
#   'discount_from': '2018-04-12T13:00:00',
#   'top28': False,
#   'url': '',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False},
#  {'rating': 200040.856418111,
#   'subtitle': '',
#   'additional_discount_currently_active': False,
#   'free_delivery_threshold': 0,
#   'delivery_fee_explanation': '배달 요금 1000원, 최소 주문 금액 10000원',
#   'is_available_delivery': True,
#   'threshold': 7500,
#   'adv_distance': None,
#   'open': True,
#   'discount_until': None,
#   'central_billing': False,
#   'city': '서울',
#   'review_reply_count': 0,
#   'sms_bonus': False,
#   'franchise_id': None,
#   'phone_downlisted': False,
#   'franchise_name': None,
#   'review_image_count': 46,
#   'top100_restaurant': False,
#   'is_available_pickup': False,
#   'additional_discount_per_menu': 0,
#   'delivery_fee': 2000,
#   'additional_discount_pickup': 0,
#   'phone': '050352583135',
#   'additional_discount_only_for_user': False,
#   'has_terminal': True,
#   'categories': ['분식', '한식', '일식돈까스'],
#   'min_order_amount': 12000,
#   'distance': 1.986494472406475,
#   'logo_url': '/media/restaurant_logos/돌솥비빔밥02_20131128_FoodAD_crop_200x200_ZskbCdb.jpg',
#   'except_cash': False,
#   'name': '조선한분식',
#   'section_pos': 19,
#   'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#   'one_dish': 0,
#   'discount_percent': 0,
#   'advertisement_type': 'contract',
#   'phone_order': True,
#   'dine_in': False,
#   'advertisement_rank': 1,
#   'thumbnail_message': '',
#   'additional_discount_pickup_per_menu': 0,
#   'open_time_description': '08:30 - 20:30',
#   'keywords': '조선한분식 분식류 수제손돈까스 뚝배기 뚝배기제육 한식류 순두부찌개 추가메뉴 공기밥 뚝배기 닭도리탕백반 한식류 김치찌개 추가메뉴 콜라1.25L 돌솥류 돌솥비빔밥 덮밥류 제육덮밥 뚝배기 뚝배기소불고기',
#   'new_rating': 1.102287672887781,
#   'app_order': True,
#   'premium': {},
#   'lng': 127.0641654,
#   'list_pos': 20,
#   'id': 224400,
#   'can_review': 0,
#   'additional_discount_pickup_only_for_user': False,
#   'review_count': 394,
#   'owner_reply_count': 0,
#   'section': 'contract',
#   'loyal_score': 22.4896641842269,
#   'thumbnail_url': '',
#   'reachable': True,
#   'additional_discount': 0,
#   'new': False,
#   'minimum_pickup_minutes': 0,
#   'has_loyalty_support': True,
#   'begin': '08:30:00',
#   'description': '',
#   'tags': [],
#   'address': '서울 광진구 자양4동 24-1번지 1층',
#   'lat': 37.5413245,
#   'end': '20:30:00',
#   'slug': '조선한식',
#   'review_avg': 4.14213197969543,
#   'discount_from': None,
#   'top28': False,
#   'url': '',
#   'payment_methods': ['creditcard', 'online'],
#   'takeout': False}]

# %%
for rest in restaurants:
    category_name = rest['categories'][0]
    category = Category.objects.get(name=category_name)
    latlng = '{lat},{lng}'.format(**rest)
    logo_url = urljoin(Yogiyo.HOST, rest['logo_url'])
    shop = Shop(category=category, name=rest['name'], latlng=latlng, meta=rest)
    
    logo_name = os.path.basename(logo_url)
    logo_data = requests.get(logo_url).content
    shop.image.save(logo_name, ContentFile(logo_data), save=False)
    print('{name}: {lat},{lng}, {categories}, {logo_url}'.format(**rest))
    
    shop.save()
# Out:
# 7번가피자-구의점: 37.5476028,127.0878279, ['프랜차이즈', '피자양식'], /media/restaurant_logos/7번가피자_20160205_Franchise이미지약정서_crop_200x200_yBpjJO6.jpg
# KFC-세종대점: 37.5472166426971,127.073569298591, ['피자양식', '프랜차이즈', '치킨'], /media/restaurant_logos/KFC__20171106_Franchise이미지약정서_crop_200x200.jpg
# 미스몽도시락-건대점: 37.5325168923834,127.077122034375, ['1인분주문', '한식'], /media/restaurant_logos/미스몽도시락-건대점_20170406_가맹로고이미지약정서_crop_200x200.jpg
# 피자샵-자양성수점: 37.5372142,127.0798521, ['피자양식', '프랜차이즈'], /media/restaurant_logos/피자샵_20160325_Franchise이미지약정서_crop_200x200_HGiPw9r.jpg
# 바다여행: 37.5614944400072,127.08213964492, ['야식', '일식돈까스'], /media/restaurant_logos/회07_20131205_foodon_crop_200x200_OTy3Hv7.jpg
# 천하대만족-중곡점: 37.5557985,127.0889371, ['야식', '족발보쌈'], /media/restaurant_logos/족발04_20131128_FoodAD_crop_200x200_3CRMM2d.jpg
# BHC-구의역점: 37.5374739,127.0843067, ['야식', '치킨', '프랜차이즈'], /media/restaurant_logos/BHC치킨_20150903_Franchise이미지약정서_crop_200x200_oJ00D1r.JPG
# 피자나라치킨공주(자양점): 37.5324453888417,127.076372946302, ['프랜차이즈', '피자양식'], /media/restaurant_logos/피자나라치킨공주_20140313_Franchise_crop_200x200_12.jpg
# 참살이임실치즈피자: 37.5378618,127.0790215, ['피자양식'], /media/restaurant_logos/참살이임실치즈피자_20131201_가맹로고_crop_200x200_cz9pwdk.jpg
# 착한삼촌닭강정: 37.5447179999388,127.0831925, ['치킨'], /media/restaurant_logos/닭강정01_20131128_FoodAD_crop_200x200_m74IoAe.jpg
# 위대한치킨(24시): 37.5682956,127.0858896, ['치킨', '야식'], /media/restaurant_logos/후라이드03_20120524_FoodAD_crop_200x200_236.jpg
# 후레쉬팩토리-광진점: 37.5471537,127.073088, ['일식돈까스', '한식', '피자양식'], /media/restaurant_logos/돈까스04_20131128_FoodAD_crop_200x200_KeABtBq.jpg
# BHC-광나루점: 37.5425784,127.0962915, ['프랜차이즈', '치킨'], /media/restaurant_logos/BHC치킨_20150903_Franchise이미지약정서_crop_200x200_yoAzedk.JPG
# 배달삼겹돼지되지-구의점: 37.5435328805089,127.092347494384, ['한식'], /media/restaurant_logos/배달삼겹돼지되지_20171122_Franchise이미지약정서_crop_200x200_qq5bajw.jpg
# 네네치킨-군자송정점: 37.5545998,127.0722369, ['치킨', '프랜차이즈'], /media/restaurant_logos/네네치킨_20131201_Franchise_crop_200x200_pHdX8dm.jpg
# 신중국관: 37.5453989810203,127.085885591623, ['중식'], /media/restaurant_logos/볶음밥01_20131128_FoodAD_crop_200x200_EF4kv1h.jpg
# 롯데리아-구의역점: 37.5363814,127.0841259, ['1인분주문', '프랜차이즈', '피자양식'], /media/restaurant_logos/롯데리아_20160408_Franchise이미지약정서_crop_200x200_s63Nq1g.jpg
# 요리왕: 37.5381341,127.0695051, ['야식', '중식'], /media/restaurant_logos/탕수육01_20120524_FoodAD_crop_200x200_11.jpg
# 파파라파피자: 37.5372392816313,127.09745446427, ['피자양식'], /media/restaurant_logos/쉬림프골드피자01_20131128_FoodAD_crop_200x200_ZHjh1SV.jpg
# 조선한분식: 37.5413245,127.0641654, ['분식', '한식', '일식돈까스'], /media/restaurant_logos/돌솥비빔밥02_20131128_FoodAD_crop_200x200_ZskbCdb.jpg

# %%
for shop in Shop.objects.all():
    restaurant_id = shop.meta['id']
    menu_list = yogiyo.get_menu_list(restaurant_id)
    #특정요청이 다시 요기요로감
    print(shop.name) #총 20개의 가게
    for sub_menu_list in menu_list: #하위 서브리스트(하위 카테고리)
        items = sub_menu_list['items']
        for item_meta in items: #특정 메타정보
            item = Item(shop=shop, name=item_meta['name'], amount=item_meta['price'], meta=item_meta)
            #이름과 가격 이미지url만 받아옴
            #Item타입의 모델 인스턴트를 생성해서 이름과 가격과 메타정보 지정
            
            item_image_url = item_meta.get('image', '') # image 가 없는메뉴, 사전표현
            if item_image_url:
                #url이 있다면
                item_image_url = urljoin(Yogiyo.HOST, item_meta['image'])
                #Yogiyo.HOST, item_meta['image']를 url join시킴
                
                item_image_name = os.path.basename(item_image_url)
                #저장할 파일명을 저장하고
                item_image_data = requests.get(item_image_url).content
                #이미지 데이터 획득해서 save를 실행햔다
                item.photo.save(item_image_name, ContentFile(item_image_data), save=False)
            print('saving item : {}'.format(item.name))
            item.save()
# Out:
# 7번가피자-구의점
# saving item : 칠리새우피자 R
# saving item : 홍대피자 R
# saving item : 탄두리야끼피자 R
# saving item : 체다골드 포테이토피자 R
# saving item : 놀부단호박피자 R
# saving item : 7번가 스페셜피자 R
# saving item : 패밀리박스（R）
# saving item : 패밀리박스（L）
# saving item : 슈퍼콤비네이션피자 R
# saving item : 핫윙（4pcs）
# saving item : 7번가 스페셜피자 R
# saving item : 프리미엄박스（R）
# saving item : 오븐 스파게티
# saving item : 프리미엄박스（L）
# saving item : 체다골드 포테이토피자 R
# saving item : 흥부 포테이토피자 R
# saving item : 와이키키피자 R
# saving item : 칠리불갈비피자 R
# saving item : 리치고구마치킨피자 R
# saving item : 해쉬베이컨피자 R
# saving item : 언더더시피자 R
# saving item : 고구마피자 R
# saving item : 와이키키피자 L
# saving item : 칠리불갈비피자 L
# saving item : 리치고구마치킨피자 L
# saving item : 해쉬베이컨피자 L
# saving item : 언더더시피자 L
# saving item : 고구마피자 L
# saving item : 칠리불갈비피자 G
# saving item : 리치고구마치킨피자 G
# saving item : 칠리새우피자 R
# saving item : 아빠와나피자 R
# saving item : 7번가 스페셜피자 R
# saving item : 놀부단호박피자 R
# saving item : 체다골드 포테이토피자 R
# saving item : 홍대피자 R
# saving item : 탄두리야끼피자 R
# saving item : 칠리새우피자 L
# saving item : 아빠와나피자 L
# saving item : 7번가 스페셜피자 L
# saving item : 놀부 단호박피자 L
# saving item : 체다골드 포테이토피자 L
# saving item : 홍대피자 L
# saving item : 탄두리야끼피자 L
# saving item : 흥부 포테이토피자 R
# saving item : 불고기피자 R
# saving item : 슈퍼콤비네이션피자 R
# saving item : 페페로니피자 R
# saving item : 더블치즈피자 R
# saving item : 흥부 포테이토피자 L
# saving item : 불고기피자 L
# saving item : 슈퍼콤비네이션피자 L
# saving item : 페페로니피자 L
# saving item : 더블치즈피자 L
# saving item : 흥부 포테이토피자 G
# saving item : 불고기피자 G
# saving item : 슈퍼콤비네이션피자 G
# saving item : 페페로니피자 G
# saving item : 더블치즈피자 G
# saving item : 고르곤졸라피자 L
# saving item : 마르게리타피자 L
# saving item : 패밀리박스（R）
# saving item : 패밀리박스（L）
# saving item : 프리미엄박스（R）
# saving item : 프리미엄박스（L）
# saving item : 치즈까르보 스파게티
# saving item : 오븐 스파게티
# saving item : 치킨 오븐텐더（5pcs）
# saving item : 화이어윙（4pcs）
# saving item : 핫윙（4pcs）
# saving item : 치즈볼（8pcs）
# saving item : 통통새우링（4pcs）
# saving item : 나폴리샐러드
# saving item : 수제피클
# saving item : 디핑소스（30g）
# saving item : 통쌀치킨（8pcs）
# saving item : 시즈닝 포테이토
# saving item : 치킨샘플러
# saving item : 콜라 500mL
# saving item : 콜라 1.25L
# saving item : 스프라이트 500mL
# saving item : 스프라이트 1.5L
# KFC-세종대점
# saving item : 블랙크리스피치킨세트
# saving item : 리얼더블징거팩
# saving item : 핫크리스피버켓세트_치즈
# saving item : 오리지널버켓세트_치즈
# saving item : 타워버거세트¸
# saving item : 스프링디저트팩
# saving item : 타워버거세트¸
# saving item : 핫크리스피치킨1조각¸
# saving item : 징거버거세트¸
# saving item : 오리지널치킨1조각¸
# saving item : 치킨도버거도세트
# saving item : 치킨너겟¸
# saving item : 징거더블다운맥스세트¸
# saving item : 징거버거¸
# saving item : 핫치즈징거버거세트¸
# saving item : 핫윙 2조각
# saving item : 블랙크리스피치킨세트
# saving item : 핫크리스피버켓세트_치즈
# saving item : 핫크리스피버켓세트_칠리
# saving item : 오리지널버켓세트_치즈
# saving item : 오리지널버켓세트_칠리
# saving item : 치킨도버거도세트
# saving item : 파티버켓세트
# saving item : 핫크리스피버켓¸
# saving item : 오리지널버켓¸
# saving item : 치키인디 1조각
# saving item : 핫크리스피치킨1조각¸
# saving item : 오리지널치킨1조각¸
# saving item : 핫크리스피치킨4조각
# saving item : 핫크리스피치킨6조각
# saving item : 치킨인디 4조각
# saving item : 치킨인디 6조각
# saving item : 치킨인디 버켓
# saving item : 블랙라벨치킨 1조각
# saving item : 블랙라벨치킨 4조각
# saving item : 블랙라벨치킨 6조각
# saving item : 블랙라벨치킨 버켓 8조각
# saving item : 리얼더블징거팩
# saving item : 징거버거세트¸
# saving item : 핫치즈징거버거세트¸
# saving item : 타워버거세트¸
# saving item : 징거더블다운맥스세트¸
# saving item : 치킨바베큐버거세트¸
# saving item : 징거버거¸
# saving item : 핫치즈징거버거¸
# saving item : 타워버거¸
# saving item : 징거더블다운맥스¸
# saving item : 치킨바베큐버거
# saving item : 스프링디저트팩
# saving item : 올쉐킷치즈¸
# saving item : 올쉐킷칠리¸
# saving item : 치킨너겟¸
# saving item : 후렌치후라이¸
# saving item : 비스켓¸
# saving item : 에그타르트¸
# saving item : 애플타르트
# saving item : 메이플피칸파이¸
# saving item : 코울슬로
# saving item : 콘샐러드
# saving item : 핫윙 1조각
# saving item : 핫윙 2조각
# saving item : 핫윙 4조각
# saving item : 텐더스트립스 1조각
# saving item : 텐더스트립스 2조각
# saving item : 텐더스트립스 4조각
# saving item : 고구마지롱치즈스틱
# saving item : 스위트칠리소스
# saving item : 버터
# saving item : 딸기잼
# saving item : 페트콜라（500ml）
# saving item : 코카콜라¸
# saving item : 코크제로
# saving item : 스프라이트
# saving item : 환타오렌지
# saving item : 캔콜라
# 미스몽도시락-건대점
# saving item : 제육볶음
# saving item : 오징어볶음
# saving item : 낙지볶음
# saving item : 오므라이스
# saving item : 새우볶음밥
# saving item : 수제생선까스
# saving item : 제육비빔밥
# saving item : 오므라이스세트（수제돈까스＋오므라이스）
# saving item : 제육볶음
# saving item : 돼지불백
# saving item : 라볶이
# saving item : 김치볶음밥＋계란후라이
# saving item : 옛날도시락＋계란후라이
# saving item : 수제돈까스
# saving item : 스팸도시락
# saving item : 참치김밥
# saving item : 옛날도시락＋계란후라이
# saving item : 야채비빔밥＋계란후라이
# saving item : 떡갈비＋계란후라이
# saving item : 칠리소스치킨볼
# saving item : 소세지야채볶음
# saving item : 스팸도시락
# saving item : 제육비빔밥
# saving item : 돼지불백
# saving item : 제육볶음
# saving item : 오징어볶음
# saving item : 낙지볶음
# saving item : 오삼불고기
# saving item : 소불고기
# saving item : 김치볶음밥＋계란후라이
# saving item : 오므라이스
# saving item : 새우볶음밥
# saving item : 미스몽김밥
# saving item : 참치김밥
# saving item : 치즈김밥
# saving item : 샐러드김밥
# saving item : 매운김밥
# saving item : 돈까스김밥
# saving item : 숯불갈비김밥
# saving item : 수제돈까스
# saving item : 수제생선까스
# saving item : 수제치킨까스
# saving item : 수제새우까스
# saving item : 수제돈＋생선까스
# saving item : 수제함박스테이크
# saving item : 수제고구마돈까스
# saving item : 수제치즈까스
# saving item : 떡볶이
# saving item : 라볶이
# saving item : 우볶이
# saving item : 쫄면
# saving item : 우동
# saving item : 오뎅
# saving item : 호박죽
# saving item : 야채죽
# saving item : 케이준샐러드
# saving item : 닭가슴살샐러드
# saving item : 오므라이스세트（수제돈까스＋오므라이스）
# saving item : 오므라이스세트（수제생선까스＋오므라이스）
# saving item : 오므라이스세트（수제고구마돈까스＋오므라이스）
# saving item : 오므라이스세트（수제치즈까스＋오므라이스）
# saving item : 우동세트（수제돈까스＋우동）
# saving item : 우동세트（수제생선까스＋우동）
# saving item : 우동세트（수제치킨까스＋우동）
# saving item : 우동세트（수제새우까스＋우동）
# saving item : 우동세트（수제돈＋생선까스＋우동）
# saving item : 우동세트（수제함박스테이크＋우동）
# saving item : 우동세트（수제고구마돈까스＋우동）
# saving item : 우동세트（수제치즈까스＋우동）
# saving item : 계란 추가
# saving item : 볶음김치 추가
# saving item : 공기밥 추가
# saving item : 국 추가
# saving item : 생수 330ml
# saving item : 콜라 캔
# saving item : 사이다 캔
# saving item : 닥터페퍼 캔
# saving item : 환타 오렌지 캔
# saving item : 웰치스 포도 캔
# saving item : 립톤아이스티 복숭아 캔
# 피자샵-자양성수점
# saving item : 수제고구마피자 R
# saving item : 치즈후라이피자 R
# saving item : 스파이시커리치킨피자 R
# saving item : 베이컨 쉬림프 피자 R
# saving item : 수제고구마피자 XXXL
# saving item : 치즈후라이피자 XXXL
# saving item :  세트1（오리지널피자L＋사이드＋콜라500mL）
# saving item : 하프앤하프피자 L
# saving item : 세트5（오리지널피자R＋사이드＋콜라500mL）
# saving item : 하프앤하프피자 R
# saving item : 치즈오븐스파게티
# saving item : 세트2（오리지널피자L＋사이드1＋사이드2＋콜라1.25L）
# saving item : 콤비네이션피자 L
# saving item : 버팔로윙（5조각）
# saving item : 콤비네이션피자 R
# saving item : 베이컨체다치즈 L
# saving item : 콤비네이션피자 R
# saving item : 불고기피자 R
# saving item : 치즈피자 R
# saving item : 야채피자 R
# saving item : 페파로니피자 R
# saving item : 하와이언피자 R
# saving item : 베이컨체다치즈 R
# saving item : 수제고구마피자 R
# saving item : 포테이토피자 R
# saving item : 치킨바베큐피자 R
# saving item : 핫치킨피자 R
# saving item : 통마늘불고기피자 R
# saving item : 쉬림프피자 R
# saving item : 핫치킨&쉬림프피자 R
# saving item : 더블바베큐피자 R
# saving item : 스파이시도이치피자 R
# saving item : 쏘핫불고기피자 R
# saving item : 치즈후라이피자 R
# saving item : 스파이시커리치킨피자 R
# saving item : 베이컨 쉬림프 피자 R
# saving item : 치즈브라운피자 R
# saving item : 콤비네이션피자 L
# saving item : 불고기피자 L
# saving item : 치즈피자 L
# saving item : 야채피자 L
# saving item : 페파로니피자 L
# saving item : 하와이언피자 L
# saving item : 베이컨체다치즈 L
# saving item : 수제고구마피자 L
# saving item : 포테이토피자 L
# saving item : 치킨바베큐피자 L
# saving item : 핫치킨피자 L
# saving item : 통마늘불고기피자 L
# saving item : 쉬림프피자 L
# saving item : 핫치킨쉬림프피자 L
# saving item : 더블바베큐피자 L
# saving item : 스파이시도이치피자 L
# saving item : 쏘핫불고기피자 L
# saving item : 치즈후라이피자 L
# saving item : 스파이시커리치킨피자 L
# saving item : 베이컨 쉬림프 피자 L
# saving item : 치즈브라운피자 L
# saving item : 콤비네이션피자 XXXL
# saving item : 불고기피자 XXXL
# saving item : 치즈피자 XXXL
# saving item : 야채피자 XXXL
# saving item : 페파로니피자 XXXL
# saving item : 하와이언피자 XXXL
# saving item : 베이컨체다치즈 XXXL
# saving item : 수제고구마피자 XXXL
# saving item : 포테이토피자 XXXL
# saving item : 치킨바베큐피자 XXXL
# saving item : 핫치킨피자 XXXL
# saving item : 통마늘불고기피자 XXXL
# saving item : 쉬림프피자 XXXL
# saving item : 핫치킨쉬림프피자 XXXL
# saving item : 더블바베큐피자 XXXL
# saving item : 스파이시도이치피자 XXXL
# saving item : 쏘핫불고기피자 XXXL
# saving item : 치즈후라이피자 XXXL
# saving item : 스파이시커리치킨피자 XXXL
# saving item : 베이컨 쉬림프 피자 XXXL
# saving item : 치즈브라운피자 XXXL
# saving item : 하프앤하프피자 R
# saving item : 하프앤하프피자 L
# saving item : 하프앤하프몬스터피자 XXXL
# saving item : 원플러스원피자 R（오리지널피자 R＋오리지널피자R）
# saving item : 원플러스원피자 L（오리지널피자L ＋오리지널피자L）
# saving item : 스위트박스1（오리지널피자R＋치즈오븐스파게티＋체다웨지감자＋치킨텐터＋핫윙）
# saving item : 스위트박스2（오리지널피자R＋오븐치킨＋그릴소세지＋크리스피포테이토）
# saving item :  세트1（오리지널피자L＋사이드＋콜라500mL）
# saving item : 세트2（오리지널피자L＋사이드1＋사이드2＋콜라1.25L）
# saving item : 세트3（오리지널피자L＋사이드＋훈제치킨＋콜라1.25L）
# saving item : 세트4（오리지널피자L＋사이드1＋사이드2＋훈제치킨＋콜라1.25L）
# saving item : 세트5（오리지널피자R＋사이드＋콜라500mL）
# saving item : 세트6（오리지널피자R＋사이드1＋사이드2＋콜라1.25L）
# saving item : 세트7（오리지널피자R＋사이드＋훈제치킨＋콜라1.25L）
# saving item : 세트8（오리지널피자R＋사이드1＋사이드2＋훈제치킨＋콜라1.25L）
# saving item : 세트9（오리지널피자L＋훈제치킨＋콜라1.25L）
# saving item : 세트10（오리지널피자R＋훈제치킨＋콜라1.25L）
# saving item : 사이드샘플러
# saving item : 치즈오븐스파게티
# saving item : 고구마스파게티
# saving item : 치킨스파게티
# saving item : 핫칠리스파게티
# saving item : 까르보나라
# saving item : 훈제치킨（한마리）
# saving item : 버팔로윙（5조각）
# saving item : 치킨텐더（4조각）
# saving item : 새우링（8조각）
# saving item : 체다웨지감자
# saving item : 오지치즈후라이
# saving item : 수제 피클
# saving item : 수제 갈릭 소스
# saving item : 핫소스
# saving item : 파마산 치즈가루
# saving item : 코카콜라 500mL
# saving item : 코카콜라 1.25L
# saving item : 스프라이트 1.5L
# saving item : 스프라이트 500mL
# 바다여행
# saving item : 광어
# saving item : 우럭
# saving item : 세트특선（광어＋우럭）
# saving item : 해산물모둠（전복＋해삼＋멍게＋개불＋가리비＋참소라＋새우＋기타계절해산물＋낙지or낙지호롱＋스끼다시5종＋초밥）
# saving item : 개불
# saving item : 멍게
# saving item : 활어＋연어초밥10pcs
# saving item : 연어초밥10pcs
# saving item : 활어초밥10pcs
# saving item : 새우초밥12pcs
# saving item : 생우럭구이
# saving item : 가리비버터구이
# saving item : 왕홍새우구이
# saving item : 대하구이
# saving item : 전복버터구이
# saving item : 회덮밥
# saving item : 모둠회（광어＋우럭＋계절활어＋연어）
# saving item : 광어
# saving item : 우럭
# saving item : 생연어
# saving item : 숭어
# saving item : 전복치（미역치）
# saving item : 놀래미
# saving item : 도미
# saving item : 농어
# saving item : 도다리세꼬시
# saving item : 아나고세꼬시
# saving item : 줄돔세꼬시
# saving item : 대광어
# saving item : 대도미（1.5kg）
# saving item : 대농어（1.5kg）
# saving item : 세트특선（광어＋우럭＋계절활어＋연어）
# saving item : 세트특선（광어＋우럭）
# saving item : 세트특선（광어＋연어）
# saving item : 세트특선（우럭＋연어）
# saving item : 세트특선（광어＋숭어）
# saving item : 세트특선（우럭＋숭어）
# saving item : 세트특선（광어＋우럭＋숭어）
# saving item : 세트특선（광어＋우럭＋아나고）
# saving item : 세트특선（광어＋우럭＋전복치）
# saving item : 세트특선（광어＋우럭＋새우튀김）
# saving item : 세트특선（광어＋우럭＋왕홍새우구이）
# saving item : 세트특선（광어＋우럭＋돌멍게）
# saving item : 세트특선（광어＋우럭＋비단멍게）
# saving item : 세트특선（광어＋우럭＋해산물모둠）
# saving item : 세트특선（광어＋우럭＋산낙지＋해산물모둠）
# saving item : 세트특선（광어＋우럭＋활랍스터찜500g）
# saving item : 산오징어물회
# saving item : 활어회물회
# saving item : 특선모둠물회
# saving item : 파티특선세트（모둠회특大＋해산물모둠＋산낙지or낙지호롱＋새우튀김＋초밥＋매운탕）
# saving item : 파티특선세트（대광어＋해산물모둠＋산낙지or낙지호롱＋새우튀김＋초밥＋매운탕）
# saving item : 파티특선세트（대도미＋해산물모둠＋산낙지or낙지호롱＋새우튀김＋초밥＋매운탕）
# saving item : 파티특선세트（능성어＋해산물모둠＋산낙지or낙지호롱＋새우튀김＋초밥＋매운탕）
# saving item : 파티특선세트（모둠회특大＋랍스터찜1kg＋해산물모둠＋산낙지or낙지호롱＋새우튀김＋초밥＋매운탕）
# saving item : 활랍스터찜1kg＋스끼다시5종＋초밥
# saving item : 활대게찜1kg＋스끼다시5종＋초밥
# saving item : 광어＋우럭＋계절활어＋해산물모둠＋초밥＋활랍스터찜1kg
# saving item : 광어＋우럭＋계절활어＋해산물모둠＋초밥＋대게찜1kg
# saving item : 해산물모둠（전복＋해삼＋멍게＋개불＋가리비＋참소라＋새우＋기타계절해산물＋낙지or낙지호롱＋스끼다시5종＋초밥）
# saving item : 개불
# saving item : 멍게
# saving item : 산낙지
# saving item : 해삼
# saving item : 전복
# saving item : 산오징어
# saving item : 오징어통찜
# saving item : 가리비찜
# saving item : 왕홍새우찜1kg
# saving item : 생우럭구이
# saving item : 전복버터구이
# saving item : 대하구이
# saving item : 왕홍새우구이
# saving item : 가리비버터구이
# saving item : 서더리매운탕
# saving item : 서더리지리맑은탕
# saving item : 생우럭매운탕
# saving item : 생우럭맑은지리탕
# saving item : 생우럭매운탕＋낙지사리
# saving item : 생우럭맑은지리탕＋낙지사리
# saving item : 연포탕（산낙지）
# saving item : 회무침
# saving item : 산오징어무침
# saving item : 낙지초무침
# saving item : 새우튀김
# saving item : 오징어튀김
# saving item : 모둠튀김（새우＋오징어＋야채튀김＋스프링롤）
# saving item : 새우초밥12pcs
# saving item : 활어초밥10pcs
# saving item : 연어초밥10pcs
# saving item : 활어＋연어초밥10pcs
# saving item : 회덮밥
# saving item : 공기밥
# saving item : 사이다500mL
# saving item : 콜라500mL
# 천하대만족-중곡점
# saving item : 훈제족발
# saving item : 반반족발（족발＋매운족발）
# saving item : 불족발
# saving item : 보쌈
# saving item : 족보세트 2~3人（족발＋보쌈＋쟁반국수）
# saving item : 가족세트（매운족발＋족발＋보쌈＋쟁반국수）
# saving item : 족보세트 2~3人（족발＋보쌈＋쟁반국수）
# saving item : 혼족（1인용）
# saving item : 훈제족발
# saving item : 반반족발（족발＋매운족발）
# saving item : 보쌈
# saving item : 족보세트 1~2人（족발＋보쌈＋쟁반국수）
# saving item : 불족발
# saving item : 쟁반막국수 中
# saving item : 족보세트 4~5人（족발＋보쌈＋쟁반국수）
# saving item : 가족세트（매운족발＋족발＋보쌈＋쟁반국수）
# saving item : 혼족（1인용）
# saving item : 훈제족발
# saving item : 반반족발（족발＋매운족발）
# saving item : 부산냉채족발
# saving item : 불족발
# saving item : 보쌈
# saving item : 혼보쌈 （1인용）
# saving item : 족보세트 1~2人（족발＋보쌈＋쟁반국수）
# saving item : 족보세트 2~3人（족발＋보쌈＋쟁반국수）
# saving item : 족보세트 4~5人（족발＋보쌈＋쟁반국수）
# saving item : 가족세트（매운족발＋족발＋보쌈＋쟁반국수）
# saving item : 쟁반막국수 中
# saving item : 쟁반막국수 大
# saving item : 공기밥
# saving item : 주먹밥
# BHC-구의역점
# saving item : 갈비레오
# saving item : 맛초킹（한마리）
# saving item : 뿌링클
# saving item : 치레카
# saving item : 붐바스틱
# saving item : 해바라기후라이드치킨
# saving item : 맛초킹（한마리）
# saving item : 뿌링클
# saving item : 해바라기후라이드치킨
# saving item : 후라이드 반／양념 반
# saving item : 맵스터
# saving item : 순살뿌링클
# saving item : 해바라기핫후라이드치킨
# saving item : 양념치킨
# saving item : 커리퀸
# saving item : 순살맛초킹
# saving item : 갈비레오
# saving item : 핫갈비레오
# saving item : 스윗츄
# saving item : 순살스윗츄
# saving item : 붐바스틱
# saving item : 스윗텐더
# saving item : 치바고
# saving item : 치바고날개
# saving item : 치바고닭다리
# saving item : 치레카
# saving item : 순살치레카
# saving item : 치레카날개¸
# saving item : 치레카다리¸
# saving item : 커리퀸
# saving item : 순살커리퀸
# saving item : 커리퀸날개¸
# saving item : 커리퀸다리¸
# saving item : 맵스터
# saving item : 순살맵스터
# saving item : 맵스터날개¸
# saving item : 맵스터다리¸
# saving item : 맛초킹（한마리）
# saving item : 순살맛초킹
# saving item : 맛초킹다리¸
# saving item : 뿌링클
# saving item : 뿌링클날개¸
# saving item : 뿌링클다리¸
# saving item : 뿌링클HOT
# saving item : 순살뿌링클
# saving item : 순살뿌링클HOT
# saving item : 바삭클
# saving item : 순살바삭클
# saving item : 해바라기후라이드치킨
# saving item : 후라이드 반／양념 반
# saving item : 해바라기핫후라이드치킨
# saving item : 해바라기닭다리후라이드치킨
# saving item : 닭날개후라이드
# saving item : 양념치킨
# saving item : 매운맛양념치킨
# saving item : 간장골드한마리
# saving item : 간장골드날개¸
# saving item : 간장골드다리¸
# saving item : 콜팝치킨
# saving item : 후렌치콜팝
# saving item : 미니콜팝
# saving item : 빅콜팝
# saving item : 뿌링콜팝
# saving item : 왕콜팝
# saving item : 케이준프라이
# saving item : 달콤바삭치즈볼
# saving item : 뿌링치즈스틱
# saving item : 콜라1.25L¸
# saving item : 사이다1.25L¸
# saving item : 치킨무
# saving item : 커리딥소스
# saving item : 뿌링뿌링소스
# 피자나라치킨공주(자양점)
# saving item : 매운양념치킨
# saving item : 후라이드치킨
# saving item : 양념치킨
# saving item : 페퍼간장치킨
# saving item : 콤비네이션피자M
# saving item : 스위트불고기피자M
# saving item : 피치세트L
# saving item : 더블포테이토피치세트M
# saving item : 스위트불고기피치세트M
# saving item : 순살피치세트M
# saving item : 더블포테이토피치세트L
# saving item : 푸실리스파게티
# saving item : 고구마피치세트M
# saving item : 스위트불고기피치세트L
# saving item : 치즈크리스피피치세트M
# saving item : 허니갈릭피치세트M
# saving item : 순살화이트어니언치킨
# saving item : 스윗콤보치킨
# saving item : 페퍼간장치킨
# saving item : 허니갈릭치킨
# saving item : 후라이드치킨
# saving item : 양념치킨
# saving item : 매운양념치킨
# saving item : 탄두리커리치킨
# saving item : 순살쉬림프골드치킨
# saving item : 치즈크리스피치킨
# saving item : 순살닭다리치킨
# saving item : 통새우불고기피자M
# saving item : 골든치즈볼피자M
# saving item : 콤비네이션피자M
# saving item : 크리미어니언피자M
# saving item : 스위트불고기피자M
# saving item : 갈릭앤갈릭피자M
# saving item : 페퍼로니피자M
# saving item : 치즈피자M
# saving item : 더블포테이토피자M
# saving item : 핫리치피자M
# saving item : 고구마피자M
# saving item : 브루스게타피자M
# saving item : 쉬림프고르곤졸라피자M
# saving item : 트리플바비큐피자M
# saving item : 통새우불고기피자L
# saving item : 골든치즈볼피자L
# saving item : 콤비네이션피자L
# saving item : 크리미어니언피자L
# saving item : 스위트불고기피자L
# saving item : 갈릭앤갈릭피자L
# saving item : 페퍼로니피자L
# saving item : 치즈피자L
# saving item : 더블포테이토피자L
# saving item : 핫리치피자L
# saving item : 고구마피자L
# saving item : 브루스게타피자L
# saving item : 쉬림프고르곤졸라피자L
# saving item : 트리플바비큐피자L
# saving item : 맵고마피치세트M
# saving item : 순살화이트어니언피치세트M
# saving item : 통새우불고기피치세트M
# saving item : 스윗콤보피치세트M
# saving item : 골든치즈볼피치세트
# saving item : 허니갈릭피치세트M
# saving item : 크리미어니언피치세트M
# saving item : 스위트불고기피치세트M
# saving item : 더블포테이토피치세트M
# saving item : 갈릭앤갈릭피치세트M
# saving item : 핫리치피치세트M
# saving item : 고구마피치세트M
# saving item : 쉬림프고르곤졸라피치세트M
# saving item : 치즈크리스피피치세트M
# saving item : 순살쉬림프골드세트M
# saving item : 순살피치세트M
# saving item : 탄두리커리피치세트M
# saving item : 트리플바비큐피치세트M
# saving item : 페퍼간장피치세트M
# saving item : 순살화이트어니언피치세트L
# saving item : 맵고마치피세트L
# saving item : 통새우불고기피치세트L
# saving item : 스윗콤보피치세트L
# saving item : 골든치즈볼피치세트L
# saving item : 허니갈릭피치세트L
# saving item : 피치세트L
# saving item : 크리미어니언피치세트L
# saving item : 스위트불고기피치세트L
# saving item : 더블포테이토피치세트L
# saving item : 갈릭앤갈릭피치세트L
# saving item : 핫리치피치세트L
# saving item : 치즈피치세트L
# saving item : 페퍼로니피치세트L
# saving item : 고구마피치세트L
# saving item : 쉬림프고르곤졸라피치세트L
# saving item : 치즈크리스피피치세트L
# saving item : 순살쉬림프골드세트L
# saving item : 순살피치세트L
# saving item : 탄두리커리피치세트L
# saving item : 트리플바비큐피치세트L
# saving item : 페퍼간장피치세트L
# saving item : 푸실리스파게티
# saving item : 스틱팩 4EA（치즈）
# saving item : 양념소스
# saving item : 매운양념소스
# saving item : 맵고마소스
# saving item : 리얼갈릭소스
# saving item : 스위트칠리소스
# saving item : 파인요거트소스
# saving item : 콜라 500mL
# saving item : 콜라 1.25L
# 참살이임실치즈피자
# saving item : 콤비네이션 피자 M
# saving item : 하와이안 피자 M
# saving item : 치즈 피자 M
# saving item : 고구마 피자 M
# saving item : 오븐스파게티
# saving item : 쉬림프골드 M
# saving item : 세트 1（피자＋치즈오븐＋요거트샐러드＋콜라 500mL）
# saving item : 피자 M＋피자 M
# saving item : 콤비네이션 피자 M
# saving item : 슈퍼슈프림 피자 L
# saving item : 콤비네이션 피자 L
# saving item : 피자 L＋피자 L
# saving item : 오븐스파게티
# saving item : 세트 2（피자＋훈제반마리＋요거트샐러드＋콜라 500mL）
# saving item : 슈퍼슈프림 피자 M
# saving item : 핫윙 7개
# saving item : 피자 M＋피자 M
# saving item : 피자 L＋피자 L
# saving item : 쉬림프핫치킨골드 M
# saving item : 쉬림프골드 M
# saving item : 치즈바이트 M
# saving item : 포테이토골드 M
# saving item : 쉬림프핫치킨골드 L
# saving item : 쉬림프골드 L
# saving item : 치즈바이트 L
# saving item : 포테이토골드 L
# saving item : 콤비네이션 피자 M
# saving item : 페페로니 피자 M
# saving item : 하와이안 피자 M
# saving item : 치즈 피자 M
# saving item : 슈퍼슈프림 피자 M
# saving item : 리치골드 피자 M
# saving item : 불고기 피자 M
# saving item : 핫불고기 피자 M
# saving item : 핫페페로니 피자 M
# saving item : 야채 피자 M
# saving item : 바베큐 피자 M
# saving item : 삼겹살 피자 M
# saving item : 베이컨치즈 피자 M
# saving item : 포테이토베이컨 피자 M
# saving item : 고구마 피자 M
# saving item : 크림치즈 피자 M
# saving item : 치킨바베큐 피자 M
# saving item : 고르곤졸라 피자 M
# saving item : 핫스파이스치킨 피자 M
# saving item : 베이컨쉬림프 피자 M
# saving item : 콤비네이션 피자 L
# saving item : 페페로니 피자 L
# saving item : 하와이안 피자 L
# saving item : 치즈 피자 L
# saving item : 슈퍼슈프림 피자 L
# saving item : 리치골드 피자 L
# saving item : 불고기 피자 L
# saving item : 핫불고기 피자 L
# saving item : 핫페페로니 피자 L
# saving item : 야채 피자 L
# saving item : 바베큐 피자 L
# saving item : 삼겹살 피자 L
# saving item : 베이컨치즈 피자 L
# saving item : 포테이토베이컨 피자 L
# saving item : 고구마 피자 L
# saving item : 크림치즈 피자 L
# saving item : 치킨바베큐 피자 L
# saving item : 고르곤졸라 피자 L
# saving item : 핫스파이스치킨 피자 L
# saving item : 베이컨쉬림프 피자 L
# saving item : 세트 1（피자＋치즈오븐＋요거트샐러드＋콜라 500mL）
# saving item : 세트 2（피자＋훈제반마리＋요거트샐러드＋콜라 500mL）
# saving item : 세트 3（피자＋버팔로윙6＋요거트샐러드＋콜라 500mL）
# saving item : 세트 4（피자＋치킨텐더5＋요거트샐러드＋콜라 500mL）
# saving item : 세트 5（피자＋후루룩떡볶이＋요거트샐러드＋콜라 500mL）
# saving item : 세트 6（피자＋치즈오븐＋훈제반마리＋요거트샐러드＋콜라 500mL）
# saving item : 세트 7（피자＋치즈오븐 or 후루룩떡볶이＋치킨텐더5 or 버팔로윙6＋요거트샐러드＋콜라 500mL）
# saving item : 세트 8（피자＋훈제한마리＋요거트샐러드＋콜라 500mL）
# saving item : 세트 9（피자＋치즈오븐＋훈제한마리＋요거트샐러드＋콜라 500mL）
# saving item : 세트 10（피자＋치즈오븐＋훈제반마리＋버팔로윙6＋요거트샐러드＋콜라 500mL）
# saving item : 치킨텐더 6조각
# saving item : 오븐스파게티
# saving item : 핫윙 7개
# saving item : 케이준감자
# saving item : 훈제 반마리
# saving item : 훈제 한마리
# saving item : 요거트 샐러드
# saving item : 후루룩떡볶이
# saving item : 콜라 500mL
# saving item : 콜라 1.25L
# saving item : 사이다 500mL
# saving item : 사이다 1.25L
# saving item : 요거트소스
# saving item : 갈릭디핑
# saving item : 꿀
# saving item : 수제피클
# saving item : 파마산（3개）
# saving item : 핫소스（3개）
# 착한삼촌닭강정
# saving item : 후라이드
# saving item : 오리지날（달콤）
# saving item : 오리지날（매콤）
# saving item : 공기밥
# saving item : 콜라 355mL
# saving item : 스프라이트 355mL
# saving item : 후라이드
# saving item : 오리지날（달콤）
# saving item : 오리지날（매콤）
# saving item : 갈릭허니（달콤）
# saving item : 갈릭허니（매콤）
# saving item : 닭강정 도시락（닭강정＋주먹밥＋반찬2）
# saving item : 떡강정
# saving item : 공기밥
# saving item : 콜라 355mL
# saving item : 콜라 1.25L
# saving item : 스프라이트 355mL
# saving item : 스프라이트 1.25L
# saving item : 수제 자몽에이드
# saving item : 갈릭허니소스 추가
# saving item : 오리지날소스 추가
# 위대한치킨(24시)
# saving item : 후라이드치킨
# saving item : 양념치킨
# saving item : 골뱅이무침
# saving item : 순살치킨
# saving item : 콜라500ml
# saving item : 콜라1.25L
# saving item : 후라이드치킨
# saving item : 양념치킨
# saving item : 핫후라이드
# saving item : 순살치킨
# saving item : 골뱅이무침
# saving item : 치킨뱅이
# saving item : 콜라500ml
# saving item : 콜라1.25L
# saving item : 사이다500ml
# saving item : 사이다1.25L
# 후레쉬팩토리-광진점
# saving item : 웰치스포도
# saving item : 웰치스딸기
# saving item : 수제등심돈가스
# saving item : 치즈돈가스
# saving item : 스테이크&볶음밥
# saving item : 양지쌀국수
# saving item : 치킨마요덮밥
# saving item : 스테이크（200g）
# saving item : 등심돈가스（추가）
# saving item : 모듬가스
# saving item : 참치김치볶음밥
# saving item : 감자튀김
# saving item : 스테이크&쌀국수
# saving item : 스테이크（200g）
# saving item : 스테이크（150g）
# saving item : 스테이크&볶음밥
# saving item : 찹스테이크덮밥
# saving item : 차돌양지볶음면
# saving item : 해물볶음면
# saving item : 새우볶음면
# saving item : 양지쌀국수
# saving item : 해물쌀국수
# saving item : 새우쌀국수
# saving item : 수제등심돈가스
# saving item : 생선가스
# saving item : 고구마가스
# saving item : 치즈돈가스
# saving item : 모듬가스
# saving item : 새우가스（6개）
# saving item : 연어회덮밥
# saving item : 참치마요덮밥
# saving item : 새우튀김마요덮밥
# saving item : 치킨마요덮밥
# saving item : 돈가스마요덮밥
# saving item : 참치김치볶음밥
# saving item : 파인애플볶음밥
# saving item : 해물볶음밥
# saving item : 새우볶음밥
# saving item : 갈릭볶음밥
# saving item : 떡갈비볶음밥
# saving item : 스테이크샐러드
# saving item : 치킨텐더샐러드
# saving item : 훈제연어샐러드
# saving item : 가리비롤
# saving item : 꽃게롤
# saving item : 새우롤
# saving item : 고구마롤
# saving item : 웨딩샤오마이
# saving item : 감자튀김
# saving item : 등심돈가스（추가）
# saving item : 생선가스（추가）
# saving item : 새우튀김（개당）
# saving item : 공기밥
# saving item : 캔사이다
# saving item : 캔콜라
# saving item : 웰치스포도
# saving item : 웰치스딸기
# saving item : 사이다 1.25L
# saving item : 콜라 1.25L
# BHC-광나루점
# saving item : 갈비레오
# saving item : 맛초킹（한마리）
# saving item : 뿌링클
# saving item : 치레카
# saving item : 붐바스틱
# saving item : 해바라기후라이드치킨
# saving item : 맛초킹（한마리）
# saving item : 해바라기후라이드치킨
# saving item : 후라이드 반／양념 반
# saving item : 뿌링클
# saving item : 커리퀸
# saving item : 순살뿌링클
# saving item : 양념치킨
# saving item : 맵스터
# saving item : 해바라기핫후라이드치킨
# saving item : 치레카
# saving item : 갈비레오
# saving item : 핫갈비레오
# saving item : 스윗츄
# saving item : 순살스윗츄
# saving item : 붐바스틱
# saving item : 스윗텐더
# saving item : 치바고
# saving item : 치바고날개
# saving item : 치바고닭다리
# saving item : 치바고날개（제）
# saving item : 치바고닭다리（제）
# saving item : 치레카
# saving item : 순살치레카
# saving item : 치레카날개¸
# saving item : 치레카다리¸
# saving item : 커리퀸
# saving item : 순살커리퀸
# saving item : 커리퀸날개¸
# saving item : 커리퀸다리¸
# saving item : 맵스터
# saving item : 순살맵스터
# saving item : 맵스터날개¸
# saving item : 맵스터다리¸
# saving item : 맛초킹（한마리）
# saving item : 순살맛초킹
# saving item : 맛초킹날개¸
# saving item : 맛초킹다리¸
# saving item : 뿌링클
# saving item : 뿌링클날개¸
# saving item : 뿌링클다리¸
# saving item : 뿌링클날개（제）
# saving item : 뿌링클HOT
# saving item : 순살뿌링클
# saving item : 순살뿌링클HOT
# saving item : 바삭클
# saving item : 순살바삭클
# saving item : 해바라기후라이드치킨
# saving item : 후라이드 반／양념 반
# saving item : 해바라기핫후라이드치킨
# saving item : 해바라기닭다리후라이드치킨
# saving item : 닭날개후라이드
# saving item : 양념치킨
# saving item : 매운맛양념치킨
# saving item : 간장골드한마리
# saving item : 간장골드날개¸
# saving item : 간장골드다리¸
# saving item : 간장골드날개（제）
# saving item : 콜팝치킨
# saving item : 후렌치콜팝
# saving item : 미니콜팝
# saving item : 빅콜팝
# saving item : 뿌링콜팝
# saving item : 왕콜팝
# saving item : 케이준프라이
# saving item : 달콤바삭치즈볼
# saving item : 뿌링치즈스틱
# saving item : 콜라1.25L¸
# saving item : 사이다1.25L¸
# saving item : 치킨무
# saving item : 양념소스
# saving item : 커리딥소스
# saving item : 뿌링뿌링소스
# 배달삼겹돼지되지-구의점
# saving item : 오리지날 솔로 도시락（200g）
# saving item : 양념 솔로 도시락（200g）
# saving item : 에네르기파삼겹 솔로 도시락（200g）
# saving item : 오리지날
# saving item : 양념
# saving item : 반반 양념
# saving item : 에네르기파삼겹
# saving item : 김치찌개
# saving item : 공기밥
# saving item : 반찬 추가
# saving item : 쌈 추가
# saving item : 어니언디핑소스
# saving item : 어니언칠리소스
# saving item : 콜라 500mL
# saving item : 콜라 1.25L
# saving item : 생수
# saving item : 모히또
# saving item : 피나콜라다
# 네네치킨-군자송정점
# saving item : 네네마늘치킨
# saving item : 후라이드
# saving item : 양념치킨
# saving item : 양념반＋후라이드반
# saving item : 순살후라이드
# saving item : 닭날개
# saving item : 양념반＋후라이드반
# saving item : 스노윙치즈＋양념
# saving item : 후라이드
# saving item : 스노윙치즈＋쇼킹핫
# saving item : 스노윙치킨
# saving item : 양념치킨
# saving item : 오리엔탈파닭
# saving item : 순살후라이드
# saving item : 순살반반（소이갈릭반＋스노윙치즈반）
# saving item : 스노윙치즈＋스노윙야채
# saving item : 크리미언
# saving item : 핫블링
# saving item : 크리미언＋핫블링
# saving item : 포테이토짜용
# saving item : 순살 소이갈릭
# saving item : 순살반반（소이갈릭반＋스노윙치즈반）
# saving item : 크리미언＋핫블링＋스노윙치즈
# saving item : 크리미언＋핫블링＋스노윙야채
# saving item : 크리미언＋핫블링＋후라이드
# saving item : 스노윙치킨
# saving item : 스노윙치즈＋스노윙야채
# saving item : 스노윙치즈＋쇼킹핫
# saving item : 스노윙치즈＋양념
# saving item : 네네마늘치킨
# saving item : 후라이드
# saving item : 양념치킨
# saving item : 양념반＋후라이드반
# saving item : 순살후라이드
# saving item : 닭날개
# saving item : 닭다리（마일드）
# saving item : 후닭 （마늘간장）
# saving item : 핫후닭 （마늘간장）
# saving item : 참나무훈제치킨
# saving item : 다리반＋날개반（마일드）
# saving item : 쇼킹핫양념치킨
# saving item : 오리엔탈파닭
# saving item : 네네볼
# saving item : 고구마치즈스틱
# saving item : 짜용소스
# saving item : 크리미언소스
# saving item : 쇼킹핫소스
# 신중국관
# saving item : 짬짜면
# saving item : 볶짜면
# saving item : 볶짬면
# saving item : 탕짜면
# saving item : 탕짬면
# saving item : 탕볶밥
# saving item : 짜장면
# saving item : 탕짜면
# saving item : 세트 1. （탕수육＋짜장1）
# saving item : 탕볶밥
# saving item : 간짜장
# saving item : 짬뽕
# saving item : 탕짬면
# saving item : 세트 2. （탕수육＋짜장2）
# saving item : 볶음밥
# saving item : 삼선짬뽕
# saving item : 짜장면
# saving item : 불쟁반짜장
# saving item : 우동
# saving item : 짬뽕
# saving item : 매운짬뽕
# saving item : 간짜장
# saving item : 기스면
# saving item : 울면
# saving item : 사천짜장
# saving item : 삼선간짜장
# saving item : 삼선짬뽕
# saving item : 고추짬뽕
# saving item : 삼선우동
# saving item : 삼선울면
# saving item : 군만두
# saving item : 물만두
# saving item : 볶음밥
# saving item : 삼선볶음밥
# saving item : 새우볶음밥
# saving item : 새우덮밥
# saving item : 잡채밥
# saving item : 고추덮밥
# saving item : 송이덮밥
# saving item : 오므라이스
# saving item : 유산슬밥
# saving item : 마파두부밥
# saving item : 잡탕밥
# saving item : 신중국관특밥
# saving item : 김치볶음밥
# saving item : 오징어덮밥
# saving item : 김치덮밥
# saving item : 제육덮밥
# saving item : 고추짬뽕밥
# saving item : 라조육밥
# saving item : 짬뽕밥
# saving item : 삼선짬뽕밥
# saving item : 탕수육
# saving item : 사천탕수육
# saving item : 오징어탕수육
# saving item : 소고기탕수육
# saving item : 양장피
# saving item : 깐풍육
# saving item : 깐풍기
# saving item : 라조기
# saving item : 잡탕
# saving item : 라조육
# saving item : 소고기 라조육
# saving item : 마파두부
# saving item : 난자완스
# saving item : 고추잡채
# saving item : 팔보채
# saving item : 잡채
# saving item : 유산슬
# saving item : 계란탕
# saving item : 누룽지탕
# saving item : 얼큰술국
# saving item : 깐쇼새우
# saving item : 깐풍새우
# saving item : 짬짜면
# saving item : 볶짜면
# saving item : 볶짬면
# saving item : 탕짜면
# saving item : 탕짬면
# saving item : 탕볶밥
# saving item : 쟁반짜장
# saving item : 볶음짬뽕
# saving item : 홍합짬뽕
# saving item : 굴짬뽕
# saving item : 콩나물짬뽕
# saving item : 홍굴이짬뽕
# saving item : 수제돈까스
# saving item : 돈까스볶음밥
# saving item : 짜장돈까스
# saving item : 삼선쟁반짬뽕
# saving item : 세트 1. （탕수육＋짜장1）
# saving item : 세트 2. （탕수육＋짜장2）
# saving item : 세트 3. （탕수육＋짬뽕2 OR 간짜장2）
# saving item : 세트 4. （탕수육＋쟁반짜장2인）
# saving item : 세트 5. （양장피＋짜장2）
# saving item : 세트 6. （팔보채＋짜장2）
# saving item : 세트 7. （고추잡채＋짜장2）
# saving item : 세트 8. （유산슬＋짜장2）
# saving item : 세트 9. （깐풍기＋짜장2）
# saving item : A코스 （양장피＋탕수육＋물만두）
# saving item : B코스 （팔보채＋양장피＋탕수육＋물만두）
# saving item : C코스 （유산슬＋깐풍기＋고추잡채＋탕수육＋물만두）
# saving item : D코스 （유산슬＋깐풍기＋깐쇼새우＋양장피＋고추잡채＋물만두）
# saving item : 육개장
# saving item : 갈비탕
# saving item : 떡국
# saving item : 떡만두국
# saving item : 만두국
# 롯데리아-구의역점
# saving item : 버거크닭세트
# saving item : 한우연인팩
# saving item : 한우명품팩
# saving item : 모짜렐라더블팩
# saving item : 버거크닭
# saving item : 비프바베큐버거
# saving item : 핫크리스피버거세트
# saving item : 치즈스틱
# saving item : 불고기버거세트
# saving item : 양념감자
# saving item : 불고기버거
# saving item : 새우버거
# saving item : 콜라1.25L（PET）
# saving item : 데리버거
# saving item : 치킨 1조각
# saving item : 화이어윙 4조각
# saving item : 버거크닭
# saving item : 비프바베큐버거
# saving item : 치킨강정버거
# saving item : 통살치킨버거
# saving item : 모짜렐라인더버거-해쉬
# saving item : 모짜렐라인더버거-더블
# saving item : 모짜렐라인더버거-베이컨
# saving item : 모짜새우버거
# saving item : AZ오리지널
# saving item : 와규오리지널
# saving item : 데리버거
# saving item : 불고기버거
# saving item : 새우버거
# saving item : 원조빅불
# saving item : 한우불고기버거
# saving item : 핫크리스피버거
# saving item : 클래식치즈버거
# saving item : 버거크닭세트
# saving item : 통살치킨버거세트
# saving item : 모짜렐라인더 버거-베이컨 세트
# saving item : 모짜렐라인더 버거-해쉬 세트
# saving item : 모짜렐라인더 버거-더블 세트
# saving item : 모짜새우버거세트
# saving item : 와규오리지널세트
# saving item : AZ오리지널세트
# saving item : 데리세트
# saving item : 불고기버거세트
# saving item : 새우버거세트
# saving item : 원조빅불세트
# saving item : 한우불고기세트
# saving item : 핫크리스피버거세트
# saving item : 클래식치즈버거 세트
# saving item : 맥앤치즈스틱1조각
# saving item : 맥앤치즈스틱2조각
# saving item : 쉑쉑치킨
# saving item : 해쉬브라운
# saving item : 양념감자
# saving item : 오징어링
# saving item : 치즈스틱
# saving item : 콘샐러드
# saving item : 포테이토
# saving item : 트위스트감자
# saving item : 롱치즈스틱
# saving item : 오렌지（PET）
# saving item : 레몬에이드
# saving item : 사이다（R）
# saving item : 아메리카노
# saving item : 아이스 아메리카노
# saving item : 아이스 카페라떼
# saving item : 카페라떼
# saving item : 콜라（R）
# saving item : 콜라1.25L（PET）
# saving item : 망고피치
# saving item : 화이어윙 2조각
# saving item : 화이어윙 4조각
# saving item : 순살치킨 풀팩
# saving item : 순살치킨 하프팩
# saving item : 치킨 1조각
# saving item : 치킨 패밀리팩
# saving item : 치킨 풀팩
# saving item : 치킨 하프팩
# saving item : 치킨휠레 2조각
# saving item : 치킨휠레 4조각
# saving item : 모짜렐라더블팩
# saving item : 한우명품팩
# saving item : 한우연인팩
# saving item : 트윈A팩
# saving item : 트윈B팩
# saving item : 홈실속A팩
# saving item : 홈실속B팩（일반）
# saving item : 데리야끼소스
# saving item : 머스타드소스
# saving item : 핫소스
# saving item : 휠레소스_허니머스타드
# saving item : 휠레소스_스위트앤샤워
# saving item : 시즈닝_치즈맛
# saving item : 시즈닝_칠리맛
# saving item : 시즈닝_오니언맛
# 요리왕
# saving item : 짬뽕
# saving item : 우동
# saving item : 간짜장
# saving item : 삼선짬뽕
# saving item : 삼선울면
# saving item : 삼선우동
# saving item : 짜장
# saving item : B 세트. 탕수육＋짜장＋짬뽕
# saving item : 짬뽕
# saving item : 간짜장
# saving item : 탕수육
# saving item : 군만두
# saving item : A 세트. 탕수육＋짜장2
# saving item : 탕볶밥
# saving item : 삼선쟁반짜장
# saving item : 탕짜면
# saving item : 목요일 정식. 고추잡채＋볶음밥＋짜장면＋꽃빵
# saving item : 목요일 할인 메뉴. 마파두부밥
# saving item : 유산슬＋볶음밥＋짜장면＋꽃빵
# saving item : 탕수육＋볶음밥＋짜장면＋꽃빵
# saving item : 마파두부＋볶음밥＋짜장면＋꽃빵
# saving item : 송이소고기볶음＋볶음밥＋짜장면＋꽃빵
# saving item : 볶음밥
# saving item : 짬뽕밥
# saving item : 짜장밥
# saving item : 김치볶음밥
# saving item : 오므라이스
# saving item : 잡채밥
# saving item : 제육덮밥
# saving item : 오징어덮밥
# saving item : 삼선볶음밥
# saving item : 새우볶음밥
# saving item : 송이밥
# saving item : 고추덮밥
# saving item : 요리왕특밥
# saving item : 삼선짬뽕밥
# saving item : 잡탕밥
# saving item : 류산슬밥
# saving item : 짜장
# saving item : 짬뽕
# saving item : 우동
# saving item : 간짜장
# saving item : 삼선간짜장
# saving item : 기스면
# saving item : 삼선짬뽕
# saving item : 삼선쟁반짜장
# saving item : 해물볶음짬뽕
# saving item : 고추짬뽕
# saving item : 삼선울면
# saving item : 삼선우동
# saving item : 불타는 쟁반짜장
# saving item : 불타는 볶음짬뽕
# saving item : 탕수육
# saving item : 사천탕수육
# saving item : 소고기탕수육
# saving item : 해물탕수육
# saving item : 오징어탕수육
# saving item : 고기잡채
# saving item : 라조육
# saving item : 라조기
# saving item : 양장피
# saving item : 깐풍기
# saving item : 팔보채
# saving item : 잡탕
# saving item : 고추잡채
# saving item : 해물누룽지탕
# saving item : 난자완스
# saving item : 류산슬
# saving item : 깐쇼새우
# saving item : 깐풍새우
# saving item : 해파리냉채
# saving item : 해삼탕
# saving item : 삼선짬뽕국물
# saving item : 삼선계란탕
# saving item : 해삼쥬스
# saving item : 짜장돈까스
# saving item : 떡만두국
# saving item : 군만두
# saving item : 물만두
# saving item : 왕만두
# saving item : 탕볶밥
# saving item : 탕짜면
# saving item : 탕짬면
# saving item : 볶짜면
# saving item : 볶짬면
# saving item : 짬짜면
# saving item : 우거지갈비탕
# saving item : 육개장
# saving item : 곰탕
# saving item : 설렁탕
# saving item : 갈비탕
# saving item : 내장탕
# saving item : 뚝배기불고기
# saving item : 굴짬뽕
# saving item : 꽃게짬뽕
# saving item : 콩나물짬뽕
# saving item : A 세트. 탕수육＋짜장2
# saving item : B 세트. 탕수육＋짜장＋짬뽕
# saving item : C 세트. 양장피＋짜장2
# saving item : D 세트. 팔보채＋짜장2
# saving item : 0-1 세트. 탕수육＋짜장 or 짬뽕
# saving item : 0-2 세트. 탕수육＋볶음밥 or 짬짜면
# saving item : 1 세트. 탕수육＋삼선쟁반짜장2人
# saving item : 2 세트. 탕수육＋해물볶음짬뽕2人
# saving item : 3 세트. 양장피＋짬뽕2
# saving item : 4 세트. 깐풍기＋짜장2
# saving item : 가 세트. 칠리탕수육＋짜장2
# saving item : 나 세트. 깐쇼새우＋짜장2
# saving item : 다 세트. 유산슬＋짜장2
# saving item : 요 세트. 탕수육＋군만두＋짬뽕국물＋잡채
# saving item : 리 세트. 양장피＋군만두＋짬뽕국물＋잡채
# saving item : 왕 세트. 탕수육＋양장피＋짬뽕국물＋군만두＋잡채
# saving item : A코스. 양장피＋탕수육＋군만두
# saving item : D코스. 양장피＋유산슬＋사천탕수육＋깐풍기＋팔보채＋고추잡채
# 파파라파피자
# saving item : 슈퍼슈프림 L
# saving item : 콤비네이션 L
# saving item : 포테이토 L
# saving item : 페퍼로니 L
# saving item : 슈퍼슈프림 King
# saving item : 콤비네이션 King
# saving item : 슈퍼슈프림 L
# saving item : 콤비네이션 L
# saving item : 포테이토 L
# saving item : 페퍼로니 L
# saving item : 치즈오븐 스파게티
# saving item : 불고기 L
# saving item : 치킨봉 （7조각）
# saving item : 군고구마 L
# saving item : 베이크 치킨
# saving item : 슈퍼슈프림 King
# saving item : 슈퍼슈프림 L
# saving item : 바베큐치킨 피자 L
# saving item : 콤비네이션 L
# saving item : 군고구마 L
# saving item : 불고기 L
# saving item : 고르곤졸라 L
# saving item : 포테이토 L
# saving item : 더블씬무스 L
# saving item : 페퍼로니 L
# saving item : 떡갈비 L
# saving item : 단호박 L
# saving item : 씨푸드 L
# saving item : 슈퍼슈프림 King
# saving item : 바베큐치킨 King
# saving item : 콤비네이션 King
# saving item : 군고구마 King
# saving item : 불고기 King
# saving item : 포테이토 King
# saving item : 페퍼로니 King
# saving item : 떡갈비 King
# saving item : 단호박 King
# saving item : 씨푸드 King
# saving item : 베이크 치킨
# saving item : 베이크치킨 （반반）
# saving item : 치즈오븐 스파게티
# saving item : 치킨봉 （7조각）
# saving item : 치킨봉 （10조각）
# saving item : 치킨윙 （7조각）
# saving item : 치킨윙 （10조각）
# saving item : 치킨텐더 （7조각）
# saving item : 치킨텐더 （10조각）
# saving item : 치즈스틱 （5조각）
# saving item : 피클
# saving item : 갈릭소스
# saving item : 치즈가루
# saving item : 핫소스
# saving item : 콜라 500mL
# saving item : 콜라 1.25L
# saving item : 사이다 500mL
# saving item : 사이다 1.25L
# 조선한분식
# saving item : 돌솥비빔밥
# saving item : 갈비탕
# saving item : 육개장
# saving item : 설렁탕
# saving item : 소내장탕
# saving item : 라볶이
# saving item : 수제손돈까스
# saving item : 뚝배기제육
# saving item : 순두부찌개
# saving item : 닭도리탕백반
# saving item : 김치찌개
# saving item : 콜라 1.25L
# saving item : 돌솥비빔밥
# saving item : 제육덮밥
# saving item : 뚝배기소불고기
# saving item : 육개장
# saving item : 돌솥비빔밥
# saving item : 돌솥김치덮밥
# saving item : 돌솥소고기비빔밥
# saving item : 돌솥참치비빔밥
# saving item : 돌솥오징어덮밥
# saving item : 돌솥제육덮밥
# saving item : 돌솥낙지덮밥
# saving item : 돌솥불고기덮밥
# saving item : 날치알솥밥
# saving item : 갈비탕
# saving item : 육개장
# saving item : 설렁탕
# saving item : 소내장탕
# saving item : 소머리국밥
# saving item : 누룽지와된장찌개
# saving item : 뚝배기제육
# saving item : 뚝배기오징어
# saving item : 뚝배기소불고기
# saving item : 뚝배기낙지
# saving item : 닭도리탕백반
# saving item : 수제손돈까스
# saving item : 수제손카레돈까스
# saving item : 짬뽕라면
# saving item : 만두라면
# saving item : 떡라면
# saving item : 유부우동
# saving item : 오뎅우동
# saving item : 라볶이
# saving item : 떡볶이
# saving item : 만두국
# saving item : 떡만두국
# saving item : 떡국
# saving item : 쫄면
# saving item : 비빔국수
# saving item : 비빔냉면
# saving item : 물냉면
# saving item : 오징어볶음大
# saving item : 오징어볶음小
# saving item : 낙지볶음大
# saving item : 낙지볶음小
# saving item : 제육볶음大
# saving item : 제육볶음小
# saving item : 김치찌개
# saving item : 된장찌개
# saving item : 순두부찌개
# saving item : 참치김치찌개
# saving item : 청국장
# saving item : 어묵백반
# saving item : 얼큰어묵
# saving item : 계란찜
# saving item : 콩비지찌개
# saving item : 부대찌개
# saving item : 김치고등어조림
# saving item : 김치꽁치조림
# saving item : 선지해장국
# saving item : 뼈다귀해장국
# saving item : 차돌박이된장찌개
# saving item : 비빔밥
# saving item : 소고기비빔밥
# saving item : 참치비빔밥
# saving item : 김치덮밥
# saving item : 참치김치덮밥
# saving item : 오징어덮밥
# saving item : 제육덮밥
# saving item : 소고기덮밥
# saving item : 낙지덮밥
# saving item : 김치볶음밥
# saving item : 새우볶음밥
# saving item : 햄김치볶음밥
# saving item : 햄야채볶음밥
# saving item : 참치김치볶음밥
# saving item : 오므라이스
# saving item : 카레라이스
# saving item : 열무비빔밥
# saving item : 열무비빔밥
# saving item : 열무비빔국수
# saving item : 비빔냉면
# saving item : 물냉면
# saving item : 공기밥
# saving item : 콜라 1.25L
# saving item : 생수 2L

# %%
host = 'http://localhost:8000'

# %%
url = 'http://test.com/admin/shop/shop/'

# %%
urljoin(host, url)
# Out:
# 'http://test.com/admin/shop/shop/'
